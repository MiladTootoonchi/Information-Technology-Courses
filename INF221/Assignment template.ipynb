# %% [markdown]
# # INF221 Assignment #
#
# <table>
#     <tr>
#         <th colspan = "2">Identification</td>
#     </tr>
#     <tr>
#         <td>Group Number</td>
#         <td>1</td>
#     </tr>
#     <tr>
#         <td>Members</td>
#         <td>
#             <ul>
#                 <li>Dan Trung Nguyen</li>
#                 <li>Håkon Bråthen Børve</li>
#                 <li>Milad Tootoonchi</li>
#             </ul>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ## Exercise 1

# %% [markdown]
# ## Exercise 2

# %% [markdown]
# ## Exercise 3

# %% [markdown]
# ## Exercise 4

# %% [markdown]
# ## Exercise 5

# %% [markdown]
# ## Exercise 6

# %% [markdown]
# ## Exercise 7
